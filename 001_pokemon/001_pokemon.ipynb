# %% [markdown]
# <a href="https://colab.research.google.com/github/so-watabe/eda-100days/blob/main/001_pokemon/001_pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello pokemon")
